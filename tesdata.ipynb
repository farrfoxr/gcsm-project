# %%
import pandas as pd

# %%
df = pd.read_csv('corn_grain_suppliers.csv')

# %%
df.head()
# Out:
#                                  certifications  \
# 0  ["KOSHER", "certified", "Verified Supplier"]
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
#
#                          company_name  \
# 0   Qingdao Wyl Imp. & Exp. Co., Ltd.
# 1                      AAZURI TRADING
# 2  Qingdao Changkun Trading Co., Ltd.
# 3                    Claris Solis LTD
# 4                   ACTION TRADING CO
#
#                                          company_url  description  \
# 0  https://wylfoods.en.alibaba.com/company_profil...          NaN
# 1  https://ca1567585481assl.trustpass.alibaba.com...          NaN
# 2  https://qingdaochangkun.en.alibaba.com/company...          NaN
# 3  https://uk1563448546ykkr.trustpass.alibaba.com...          NaN
# 4  https://us29165018365ecjm.trustpass.alibaba.co...          NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   certifications                48 non-null     object
#  1   company_name                  48 non-null     object
#  2   company_url                   48 non-null     object
#  3   description                   0 non-null      float64
#  4   location_search_page          48 non-null     object
#  5   min_order                     48 non-null     object
#  6   price                         48 non-null     object
#  7   product_title                 48 non-null     object
#  8   product_url                   48 non-null     object
#  9   response_rate                 2 non-null      object
#  10  years_on_alibaba_search_page  48 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 4.2+ KB
